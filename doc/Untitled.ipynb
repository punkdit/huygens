# %%
from huygens import canvas, style, color
from huygens.turtle import Turtle

# %%
cvs = canvas.canvas()
turtle = Turtle(cvs=cvs)

n = 8
angle = 360. / n
R = 3.0
for i in range(n):
    turtle.fwd(1.*R)
    turtle.left((1./3)*angle)
    turtle.back(0.5*R)
    turtle.left((1./3)*angle)
    turtle.back(0.7*R)
    turtle.left((1./3)*angle)
    turtle.stroke()

# %%
cvs
# Out:
# Canvas(items=[Compound(items=[LineWidth(lw=0.014142135623730949), LineCap(desc=ROUND), LineJoin(desc=ROUND), Path(items=[MoveTo(x=0.0, y=0.0), LineTo(x=0.0, y=3.0), LineTo(x=0.3882285676537811, y=1.5511112605663975), LineTo(x=1.4382285676537807, y=-0.26754208738092355)]), Stroke()]), Compound(items=[LineWidth(lw=0.014142135623730949), LineCap(desc=ROUND), LineJoin(desc=ROUND), Path(items=[MoveTo(x=1.4382285676537807, y=-0.26754208738092355), LineTo(x=-0.6830917759058617, y=1.8537782561787193), LineTo(x=0.6159463297707963, y=1.103778256178719), LineTo(x=2.644390564977839, y=0.5602582614634252)]), Stroke()]), Compound(items=[LineWidth(lw=0.014142135623730949), LineCap(desc=ROUND), LineJoin(desc=ROUND), Path(items=[MoveTo(x=2.644390564977839, y=0.5602582614634252), LineTo(x=-0.3556094350221608, y=0.560258261463426), LineTo(x=1.0932793044114417, y=0.9484868291172066), LineTo(x=2.9119326523587628, y=1.998486829117206)]), Stroke()]), Compound(items=[LineWidth(lw=0.014142135623730949), LineCap(desc=ROUND), LineJoin(desc=ROUND), Path(items=[MoveTo(x=2.9119326523587628, y=1.998486829117206), LineTo(x=0.7906123087991199, y=-0.1228335144424364), LineTo(x=1.54061230879912, y=1.1762045912342216), LineTo(x=2.084132303514413, y=3.2046488264412645)]), Stroke()]), Compound(items=[LineWidth(lw=0.014142135623730949), LineCap(desc=ROUND), LineJoin(desc=ROUND), Path(items=[MoveTo(x=2.084132303514413, y=3.2046488264412645), LineTo(x=2.084132303514414, y=0.20464882644126448), LineTo(x=1.6959037358606321, y=1.6535375658748668), LineTo(x=0.6459037358606312, y=3.472190913822187)]), Stroke()]), Compound(items=[LineWidth(lw=0.014142135623730949), LineCap(desc=ROUND), LineJoin(desc=ROUND), Path(items=[MoveTo(x=0.6459037358606312, y=3.472190913822187), LineTo(x=2.7672240794202754, y=1.350870570262546), LineTo(x=1.4681859737436171, y=2.1008705702625456), LineTo(x=-0.5602582614634259, y=2.6443905649778388)]), Stroke()]), Compound(items=[LineWidth(lw=0.014142135623730949), LineCap(desc=ROUND), LineJoin(desc=ROUND), Path(items=[MoveTo(x=-0.5602582614634259, y=2.6443905649778388), LineTo(x=2.439741738536574, y=2.6443905649778383), LineTo(x=0.9908529991029713, y=2.2561619973240576), LineTo(x=-0.8278003488443504, y=1.2061619973240592)]), Stroke()]), Compound(items=[LineWidth(lw=0.014142135623730949), LineCap(desc=ROUND), LineJoin(desc=ROUND), Path(items=[MoveTo(x=-0.8278003488443504, y=1.2061619973240592), LineTo(x=1.2935199947152947, y=3.3274823408836993), LineTo(x=0.5435199947152929, y=2.0284442352070426), LineTo(x=-4.107825191113079e-15, y=4.440892098500626e-16)]), Stroke()])])

# %%
attrs = [style.linewidth.THIck, color.rgb(0.2, 0.6, 0.2)]

cvs = canvas.canvas()
turtle = Turtle(cvs=cvs, attrs=attrs)

turtle.fwd(2.)
turtle.right(300, 1.)
turtle.fwd(2.)
turtle.arrow(0.4)
turtle.stroke()

# %%
cvs
# Out:
# Canvas(items=[Compound(items=[LineWidth(lw=0.08), RGBA(cl=(0.2, 0.6, 0.2, 1.0)), Path(items=[MoveTo(x=0.0, y=0.0), LineTo(x=0.0, y=2.0), LineTo(x=0.008555138626189618, y=2.1305261922200516), LineTo(x=0.03407417371093169, y=2.2588190451025207), LineTo(x=0.07612046748871326, y=2.3826834323650896), LineTo(x=0.13397459621556151, y=2.5), LineTo(x=0.20664665970876483, y=2.6087614290087204), LineTo(x=0.2928932188134524, y=2.7071067811865475), LineTo(x=0.39123857099127957, y=2.7933533402912354), LineTo(x=0.5000000000000004, y=2.866025403784439), LineTo(x=0.6173165676349106, y=2.923879532511287), LineTo(x=0.7411809548974795, y=2.965925826289068), LineTo(x=0.8694738077799489, y=2.9914448613738105), LineTo(x=1.0000000000000007, y=3.0), LineTo(x=1.1305261922200522, y=2.9914448613738105), LineTo(x=1.2588190451025212, y=2.965925826289068), LineTo(x=1.3826834323650905, y=2.9238795325112865), LineTo(x=1.5000000000000004, y=2.8660254037844384), LineTo(x=1.6087614290087209, y=2.793353340291235), LineTo(x=1.7071067811865477, y=2.7071067811865475), LineTo(x=1.793353340291235, y=2.608761429008721), LineTo(x=1.8660254037844388, y=2.4999999999999996), LineTo(x=1.9238795325112865, y=2.3826834323650905), LineTo(x=1.9659258262890682, y=2.2588190451025207), LineTo(x=1.9914448613738103, y=2.1305261922200525), LineTo(x=2.0, y=2.0), LineTo(x=1.9914448613738105, y=1.8694738077799495), LineTo(x=1.9659258262890684, y=1.7411809548974797), LineTo(x=1.9238795325112874, y=1.6173165676349117), LineTo(x=1.866025403784439, y=1.5000000000000007), LineTo(x=1.7933533402912363, y=1.391238570991281), LineTo(x=1.7071067811865483, y=1.2928932188134532), LineTo(x=1.6087614290087218, y=1.2066466597087655), LineTo(x=1.5000000000000013, y=1.133974596215562), LineTo(x=1.3826834323650912, y=1.076120467488714), LineTo(x=1.2588190451025225, y=1.0340741737109322), LineTo(x=1.1305261922200533, y=1.00855513862619), LineTo(x=1.000000000000002, y=1.0), LineTo(x=0.8694738077799505, y=1.0085551386261893), LineTo(x=0.7411809548974815, y=1.0340741737109311), LineTo(x=0.6173165676349125, y=1.0761204674887122), LineTo(x=0.5000000000000022, y=1.13397459621556), LineTo(x=-1.232050807568875, y=2.1339745962155603)]), Stroke()]), Compound(items=[LineWidth(lw=0.08), RGBA(cl=(0.2, 0.6, 0.2, 1.0)), Path(items=[MoveTo(x=-1.032050807568875, y=1.7875644347017847), LineTo(x=-1.232050807568875, y=2.1339745962155603), LineTo(x=-0.832050807568875, y=2.13397459621556)]), Stroke()])])

# %%
cvs = canvas.canvas()
turtle = Turtle(cvs=cvs, attrs=attrs)

R = 1.0
for i in range(24*2):
    turtle.left(320, 0.6*R)
    turtle.left(-60, 0.3*R)
    turtle.right(90, 0.6*R)
    turtle.stroke(attrs=attrs)

# %%
cvs
# Out:
# Canvas(items=[Compound(items=[LineWidth(lw=0.08), RGBA(cl=(0.2, 0.6, 0.2, 1.0)), Path(items=[MoveTo(x=0.0, y=0.0), LineTo(x=-0.005839158755057805, y=0.08350386057603931), LineTo(x=-0.02324298243700862, y=0.16538241349019953), LineTo(x=-0.051872725414439436, y=0.24404198584548023), LineTo(x=-0.09117114230614443, y=0.31795155853992296), LineTo(x=-0.1403733341286132, y=0.38567256581192366), LineTo(x=-0.19852163618468505, y=0.4458868952864366), LineTo(x=-0.26448425791755187, y=0.497422543533025), LineTo(x=-0.33697731192655356, y=0.5392764277795002), LineTo(x=-0.41458980337503154, y=0.570633909777092), LineTo(x=-0.49